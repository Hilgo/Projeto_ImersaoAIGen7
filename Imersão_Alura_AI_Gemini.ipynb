# %% [markdown]
# <a href="https://colab.research.google.com/github/Hilgo/Projeto_ImersaoAIGen7/blob/main/Imers%C3%A3o_Alura_AI_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
#Configurações iniciais
import google.generativeai as genai
from google.colab import userdata
import numpy as np
import pandas as pd

GOOGLE_API_KEY= userdata.get("SECRET_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ## Generate text

# %%
response = model.generate_content("Write a story about a magic backpack.")
print(response.text)

# %% [markdown]
# Listar modelos

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# Inicializando Modelo

# %%
generation_config = {
    "candidate_count":1,
    "temperature":0.5
}

safety_settings = {
    "HARASSMENT":"BLOCK_NONE",
    "HATE":"BLOCK_NONE",
    "SEXUAL":"BLOCK_NONE",
    "DANGEROUS":"BLOCK_NONE"
}

model = genai.GenerativeModel(model_name = "gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
chat = model.start_chat(history=[])

# %%
prompt = input("Esperando prompt: ")

while prompt != "fim":
  response = chat.send_message(prompt)
  print("Reposta: ", response.text, "\n")
  prompt = input("Esperando prompt: ")

# %%
chat

# %%
#Melhorando a visualização
#Código disponível em https://ai.google.dev/tutorials/python_quickstart#import_packages
import textwrap
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

#Imprimindo o histórico
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
  print('-------------------------------------------')

# %%
#Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título": "SUMÁRIO PARA O OFICIAL",
    "Conteúdo": "Bem-vindo ao seu novo turno! Para ajudá-lo a se recuperar da hibernação, aqui está um breve resumo sobre nossa nave, os diversos locais dentro dela e as funções desses locais. O espaço habitável da nave é chamado habitat. É uma estrutura hexagonal com múltiplos níveis e um casco externo sem janelas, maximizando a proteção contra radiação e colisão de partículas. Tem gravidade artificial, criada pela nave, oscilando entre estados de aceleração e desaceleração constantes. A partir dos 10 anos, todos os tripulantes devem realizar uma rotina anual de um turno de quatro meses de serviço seguido por oito meses de hibernação. A administração da nave é liderada por você e pelos outros membros da equipe de comando, e é auxiliada por três divisões de sistemas: Computação, Energia e Biosfera. Novas tarefas de operações são obtidas em Operações. Uma reunião pode ser convocada por um oficial ou por um colono, que vai então atuar na função de chefe de operações até a próxima reunião. A inteligência artificial (IA) da nave é chamada de CARE-N. CARE-N pilota a nave e monitora seus sistemas, atribuindo aos oficiais tarefas críticas quando um componente precisa de manutenção urgente. Responder rapidamente às tarefas críticas de CARE-N será da maior importância para o sucesso da missão, e é seu dever como oficial. O Depósito da Nave é usado para armazenar os recursos necessários para completar as tarefas críticas atribuídas por CARE-N. Tarefas críticas contêm assentos de grupo que devem ser preenchidos, muitas vezes por membros de diversos quartéis, para evitar que o desempenho dos sistemas da nave se degrade. Os indicadores de status do sistema monitoram o nível de desempenho dos três sistemas críticos para a sobrevivência do habitat. Conforme um sistema se degrada, assentos em sua divisão ficam indisponíveis para uso. Laboratórios produzem fichas de recurso, que são necessárias para completar a maioria das tarefas críticas e todas as tarefas de operações. Centros são onde as tarefas de operações são completadas e também proporcionam ferramentas úteis de produtividade. Tripulantes adicionais para os quartéis podem ser acordados da hibernação por solicitação de um oficial para o Centro Médico. Robótica fornece robôs que podem ser programados para uma vasta gama de funções. Seus esforços incansáveis são especialmente úteis quando designados para a conclusão de tarefas críticas. É bom ter você de volta conosco em nossa viagem de 210 anos até o sistema Epsilon Eridani!"}

DOCUMENT2 = {
    "Título": "OBJETIVO DO JOGO",
    "Conteúdo": "Em Gen7, os jogadores são oficiais da sétima geração de colonos a bordo de uma arca interestelar viajando para o sistema Epsilon Eridani. A nave já completou 142 dos 210 anos da sua missão. Cada sessão de jogo é chamada de 'episódio'. Os jogadores receberão objetivos do episódio que devem completar para receber estrelas de oficial, que são usadas para ganhar privilégios de oficial. Os jogadores trabalharão independentemente para ganhar mais estrelas de oficial, mas também devem trabalhar cooperativamente para fazer avançar a trama do episódio e impedir que os sistemas da nave falhem. Uma partida completa de Gen7 ocorre em sete episódios, durante os quais escolhas de jogo e de narrativas afetarão o resultado final da história. OBSERVAÇÕES IMPORTANTES: Gen7 é um jogo narrativo. A partida não é vencida ou perdida até a conclusão da história. Cada episódio define objetivos que os jogadores devem alcançar para avançar e que acabará por definir as condições que vão determinar a vitória. Entretanto, a conclusão da história e se a vitória será conquistada ou não dependerá das ações dos jogadores, e NÃO pelo total de estrelas de oficiais obtidas nos episódios. Gen7 também é um jogo de campanha. Novos elementos de jogo serão introduzidos ao longo da partida. Alguns elementos talvez nunca venham a ser introduzidos, dependendo das ações dos jogadores. Por isso, você pode encontrar termos, símbolos ou valores nos materiais de jogo que não são definidos neste livro de regras, mas que serão definidos se esses elementos entrarem em jogo. Seja paciente e explore suas possibilidades"}

DOCUMENT3 = {
    "Título": "COMPONENTES",
    "Conteúdo": "DADOS DE TRIPULANTE (Verde, Azul, Laranja, Roxo) D12 Robô D8 Oficial D6 Colono Nota: Os termos tripulante, dado/dados e dados de tripulante são intercambiáveis.FICHAS DE RECURSO Dados Peça Produto Químico INSÍGNIAS Chefe de Operações MARCADORES Ponto de Mérito (Verde, Azul, Laranja, Roxo) Tripulante em Hibernação (Verde, Azul, Laranja, Roxo) Sucesso Falha Desabilitado Rodada (Atual, Final) Avanço da Trama" }

DOCUMENT4 = {
    "Título": "CARTAS DE TAREFA CRÍTICA ",
    "Conteúdo": "Nome: O nome da tarefa crítica. 2. Divisão: A divisão à qual a tarefa crítica pertence. 3. Recursos: Os recursos necessários para completar a tarefa. 4. Assentos de Grupo: O número de assentos que deve ser preenchido com dados de tripulante, assim como a regra de relacionamento que deve ser seguida. 5. Recompensa em Mérito: O número de pontos de mérito concedidos a cada jogador que contribuiu com pelo menos um dado de tripulante. 6. Falha do Sistema: O efeito negativo se a tarefa crítica não for completada até o fim da rodada. O sistema da nave será degradado esse número de níveis. 7. Ícone do Assento de Grupo: Um lembrete de que os assentos são um assento de grupo."}

DOCUMENT5 = {
    "Título": "CARTAS DE TAREFA DE OPERAÇÕES",
    "Conteúdo": "Nome: O nome da carta de tarefa de operações. 2. Recursos: Os recursos necessários para completar a tarefa. 3. Centro: O local da nave onde a tarefa deve ser completada. 4. Recompensa em Mérito: Os pontos de mérito concedidos ao jogador que completou a tarefa. 5. Penalidade em Mérito: Os pontos de mérito deduzidos do jogador que ainda estiver com a tarefa no final do episódio. 6. Texto Especial: Instruções especiais para seguir quando a tarefa for completada."}

DOCUMENT6 = {
    "Título": "CARTAS DE ARQUIVO",
    "Conteúdo": "Nome: O nome da carta de arquivo. 2. Efeito: O efeito que ocorre quando a carta de arquivo é jogada."}

DOCUMENT7 = {
    "Título": "CARTAS DE ESQUEMA",
    "Conteúdo": "Nome: O nome da carta de esquema. 2. Efeito: O efeito contínuo da carta de esquema quando ela é colocada em um quartel. 3. Foco: O texto do efeito (entre colchetes) que é substituído quando uma carta de esquema está em foco. Consulte 'Cartas de Esquema' nas páginas 16-17."}

DOCUMENT8 = {
    "Título": "CARTAS DE ENCRUZILHADA",
    "Conteúdo": "Nome: O nome da carta de encruzilhada. 2. Identificação: A identificação do grupo da carta. 3. Gatilho: Os critérios que determinam se os efeitos da carta acontecem. 4. Opções: As opções disponíveis quando a carta é ativada."}

DOCUMENT9 = {
    "Título": "CARTAS DE OBJETIVO DE EPISÓDIO",
    "Conteúdo": "Nome: O nome do objetivo. 2. Estado: O estado atual do objetivo (sucesso ou fracasso). 3. Critérios: Os critérios para completar o objetivo e as estrelas recebidas por completá-lo. 4. Fracasso: Os critérios que fazem com que esta ou outras cartas de objetivos sejam viradas para o lado 'fracasso'."}

DOCUMENT10 = {
    "Título": "CARTAS DE OBJETIVO PESSOAL",
    "Conteúdo": "Nome: O nome do objetivo. 2. Critérios: Os critérios para completar o objetivo. 3. Estrelas de Oficial: As estrelas de oficial recebidas por completar o objetivo."}

DOCUMENT11 = {
    "Título": "CARTAS DE TRIPULANTE",
    "Conteúdo": "Nome: O nome do tripulante. 2. Posto na Nave: A função do tripulante na nave. 3. Avaliação de Desempenho: O desempenho atual do tripulante. 4. Adição às Encruzilhadas: Cada carta de tripulante instrui que uma carta de encruzilhada específica deve ser adicionada ao baralho de encruzilhada. Isso deve ser feito quando a carta é entregue a um jogador no primeiro episódio."}

DOCUMENT12 = {
    "Título": "CARTAS DE REGRAS",
    "Conteúdo": "Nome: O nome da carta. 2. Regras: As regras que devem ser seguidas para usar os elementos de jogo referenciados. Essas cartas serão introduzidas quando um novo elemento entrar em jogo, e podem ser consultadas até esse elemento se tornar familiar."}

DOCUMENT13 = {
    "Título": "TABULEIROS DE LOCAIS DA NAVE",
    "Conteúdo": "Nome: O nome do local da nave. 2. Divisão: A cor da borda indica a divisão à qual o local pertence, o que muitas vezes corresponde a um sistema da nave que governa o local. 3. Assentos: Os assentos disponíveis para colocar tripulantes. O número de pontos indica se um marcador de falha deve ser colocado sobre eles quando um sistema se degrada. Os assentos podem ser ocupados em qualquer ordem. 4. Ações: As ações que ocorrem quando um tripulante é colocado no local. Se houver mais de uma ação listada, elas ocorrem na ordem listada. Se uma ação estiver em itálico, ela é opcional."}

DOCUMENT14 = {
    "Título": "TABULEIRO DE TRILHAS",
    "Conteúdo": "Trilha de Mérito: Registra os pontos de mérito ganhos pelos jogadores. 2. Trilha / : Registra as decisões dos jogadores e ajuda a guiar a história durante as votações dos jogadores no livro da trama. 3. Trilha de Rodada: Registra a rodada atual, avanço da trama e rodada final."}

DOCUMENT15 = {
    "Título": "DIÁRIO DE BORDO",
    "Conteúdo": "Nome da Nave: Espaço reservado para os jogadores batizarem a nave. 2. Oficiais: Espaço reservado para os jogadores batizarem seus oficiais e registrarem seus postos. 3. Condição: Caixas usadas para monitorar a condição geral da nave e da tripulação. 4. Notas: Espaço reservado para notas, conforme instruído. 5. Registro da Tripulação: Espaço reservado para atualizações do registro da tripulação, conforme instruído. 6. Relatório do Episódio: Usado para registrar o Melhor Oficial de cada episódio e qual é seu estado de / cada episódio. ao final de cada episódio"}

DOCUMENT15 = {
    "Título": "CARTELA DE QUARTEL",
    "Conteúdo": "Nome: O nome do quartel. 2. Depósito de Recursos: Esta seção é reservada para armazenar fichas de recursos coletadas. Note o limite de armazenamento indicado. 3. Referência dos Dados de Tripulante: Lembrete dos tipos de dados. 4. Alojamento da Tripulação: Esta seção é reservada para armazenar os dados de tripulante não usados. 5. Espaços para Esquemas: Espaços reservados para as cartas adquiridas pelo jogador. 6. Habilidade Única: Uma descrição da habilidade única do quartel. Os laboratórios particulares são locais da nave disponíveis apenas para o jogador que controla esse quartel e não são parte de nenhuma divisão. 7. Privilégios de Oficial: Espaços para os privilégios de oficial que o jogador já adquiriu."}

DOCUMENT16 = {
    "Título": "PRIVILÉGIOS DE OFICIAL",
    "Conteúdo": "Nome: O nome do privilégio de oficial. 2. Custo em Estrelas: O custo, em estrelas de oficial, para adquirir o privilégio. 3. Habilidade: A habilidade obtida pelo jogador que tem o privilégio. 4. Requerimento de Posto: Indica o posto que o oficial deve ter para adquirir o privilégio."}

DOCUMENT17 = {
    "Título": "LIVRO DA TRAMA",
    "Conteúdo": "Preparação do Episódio: Preparação adicional específica para o episódio. 2. Objetivos do Episódio: As cartas de objetivo do episódio usadas. 3. Introdução / Avanço da Trama: Narrativa para avançar a história do episódio. 4. Trama: O próximo objetivo narrativo que deve ser alcançado. 5. Preparação Especial: Preparação adicional realizada durante um episódio. 6. Regras Especiais: Regras específicas do episódio que se aplicam enquanto os jogadores tentam alcançar o objetivo atual da trama. 7. Avanço: Instruções sobre como avançar para a próxima página do livro da trama. 8. Efeito de Contratempo: A penalidade infligida aos jogadores se o objetivo da trama não for completado com sucesso"}

DOCUMENT18 = {
    "Título": "OUTROS COMPONENTES",
    "Conteúdo": "Dado de Tripulante Robô Dado de Tripulante Oficial Rodada Atual Avanço da Trama Rodada Final Marcadores de Rodada Dado de Tripulante Colono 1 1 1 Fichas de Recurso Insígnia de Chefe de Operações Ficha de Oficial em Destaque Marcador Lógica/Instinto Marcador de Página Marcador de Falha Marcador de Desabilitado Marcador de Sucesso Marcador de Tripulante em Hibernação Marcadores de Pontos de Mérito"}

DOCUMENT19 = {
    "Título": "PREPARAÇÃO",
    "Conteúdo": "PASSOS DE PREPARAÇÃO ADICIONAIS PARA O PRIMEIRO EPISÓDIO: Peguem um diário de bordo para esta campanha e batizem sua nave (A). Cada jogador dá um nome para seu oficial e o registra no Diário de Bordo (B). Embaralhem e distribuam 1 carta de tripulante a cada jogador (C). Enquanto um jogador continua a preparação, passem o “Sumário Para o Oficial” (no verso das páginas do Diário de Bordo) para cada jogador ler, ou escolham um jogador para lê-lo em voz alta. Coloquem o marcador / na posição 0 da trilha PASSOS DE PREPARAÇÃO ADICIONAIS PARA OS EPISÓDIOS SUBSEQUENTES: Peguem o Diário de Bordo desta campanha. Verifiquem o valor de / / registrado no episódio anterior e coloquem o marcador / na trilha / de acordo. Distribuam as cartas guardadas de cada jogador, incluindo privilégios de oficial e carta de tripulante. Entreguem o marcador de 'oficial em destaque' ao melhor oficial do episódio anterior. PASSOS DE PREPARAÇÃO PARA TODOS OS EPISÓDIOS: 1. Coloquem os tabuleiros de locais da nave no centro da área de jogo conforme mostrado no exemplo de preparação, e coloquem um marcador de sucesso no quadrado verde em cada trilha de status do sistema. Apenas para partidas com 3 jogadores: Cubram todos os assentos com 3 pontos com um marcador de falha. Esses assentos não estão disponíveis a menos que um efeito especial indique o contrário. 2. Coloquem o marcador de rodada atual na posição 1 da trilha de rodada. 3. Coloquem o Livro da Trama perto da área de jogo, aberto na primeira página do episódio atual (1.00 para o primeiro episódio) e sigam quaisquer instruções de preparação especiais, além de qualquer preparação para os objetivos indicados do episódio. 4. Separem as fichas e marcadores e coloquem-nas na área de suprimentos, conforme mostrado no exemplo de preparação. e 3 fichas de . no local 5. Coloquem 3 fichas de , 3 fichas de 'Depósito da Nave'. 6. Coloquem quaisquer cartas de regras desbloqueadas perto da área de jogo (a campanha começa com duas cartas de regras desbloqueadas: 'Reunião de Operações' e 'Fichas de Recurso'). 7. Distribuam aleatoriamente uma cartela de quartel para cada jogador. Cada jogador pega os seguintes dados de tripulante da cor do seu quartel: 1 oficial, 1 robô, 5 colonos. Nota: O Quartel de Robótica (se estiver no jogo) tem um dado de colono a menos, mas coloca seu dado de robô no quartel em vez de colocá-lo no suprimento. 8. Cada jogador coloca seu marcador de tripulante em hibernação na Sala de Recuperação, seu robô no suprimento ao lado de Robótica e dois dos seus colonos no suprimento ao lado do Centro Médico. O resto dos dados são colocados na seção 'alojamento dos tripulantes' da sua cartela de quartel. 9. Realizem os passos de preparação do jogo para cada um dos quartéis (se houver) e coloquem os marcadores de pontos de mérito em 0 na Trilha de Mérito. 10. Embaralhem os baralhos de encruzilhadas, tarefas críticas, arquivos e esquemas e os coloquem-nos em seus tabuleiros. Distribuam 1 carta de arquivo e 1 carta de esquema para cada jogador. Coloquem a carta de encruzilhada de suporte no topo do baralho de encruzilhada. 11. Todos os jogadores rolam seus dados de oficial. O resultado mais baixo recebe a insígnia de chefe de operações (rolem novamente para desempatar se necessário). Esse jogador começa o episódio na primeira posição, seguido pelos outros jogadores em sentido horário. 12. Embaralhem o baralho de tarefas de operações e o coloquem no seu tabuleiro. Comprem 2x + 1 cartas de tarefas de operações (x é o número de jogadores) e entreguem-nas para o jogador na última posição. Em sentido anti-horário, cada jogador escolhe uma das cartas de tarefa de operações e passa o restante. Quando todos os jogadores tiverem duas cartas, coloquem a carta restante virada para cima no fundo do baralho de tarefas de operações. 13. Abram a próxima página do livro da trama e leiam o texto em voz alta. (Elementos do jogo podem ser lidos por qualquer jogador, a menos que especificado em contrário). 14. Comecem a primeira rodada"}

DOCUMENT20 = {
    "Título": "RODADA",
    "Conteúdo": "Gen7 é jogado ao longo de diversas rodadas, definidas pelo episódio atual. Cada rodada tem sete fases. 1. Tarefas Críticas 2. Rolar a Tripulação 3. Turnos dos Jogadores 4. Falha do Sistema 5. Recuperar a Tripulação 6. Atualizar o Status 7. Fim da Rodada 1. TAREFAS CRÍTICAS Um certo número de cartas de tarefa crítica são compradas do baralho e colocadas, viradas para cima, na fila de tarefas críticas. O número de cartas compradas é determinado pelo número de jogadores e pela rodada atual. Para mais informações sobre quantas tarefas críticas são compradas a cada rodada, consulte a tabela no tabuleiro de tarefas críticas. 2. ROLAR A TRIPULAÇÃO Todos os jogadores rolam os dados de tripulante que estão na área 'Alojamento da Tripulação' da sua cartela de quartel. 3. TURNOS DOS JOGADORES Os jogadores vão jogar seus turnos realizando uma ação por vez, em sentido horário, a partir do chefe de operações, até que todos passem a vez. UM TURNO Durante o turno de um jogador, ele é considerado o 'jogador ativo'. Em seu turno, o jogador ativo deve colocar um dado de tripulante do seu quartel em um assento desocupado. Se o jogador ativo tiver tripulantes no seu quartel, ele DEVE colocar um dado como parte do seu turno. Se ele não puder colocar nenhum dado, um dos seus dados de tripulante deve ser colocado na Sala de Recuperação do Centro Médico. Nota: O resultado do dado não precisa ser igual ao número de pontos no assento, mas alguns assentos (por exemplo assentos de grupo) têm regras de colocação que devem ser seguidas. No caso dos assentos de grupo, pode ser colocado mais de um dado. O jogador ativo pode escolher preencher todos os assentos com dados do seu quartel, ou pode pedir para que os outros jogadores contribuam com tripulantes para preencher os assentos coletivamente. O jogador ativo deve colocar pelo menos um dado e os assentos de grupo devem ser preenchidos simultaneamente (ou seja, você não pode ocupar um dos assentos de grupo e adicionar mais tripulantes em outro turno). Depois de colocar tripulantes em um local da nave, as ações desse local são realizadas. Títulos de ação em itálico são opcionais. CARTAS DE ARQUIVO Um jogador pode jogar quantas cartas de arquivo quiser da sua mão a qualquer momento durante seu turno ou quando estiver contribuindo com tripulantes para um assento de grupo. Se uma carta puder ser jogada durante o turno de outro jogador, isso estará indicado especificamente na carta. CARTA DE ENCRUZILHADA No final de um turno, é comprada uma carta de encruzilhada se qualquer um dos tripulantes colocados for um oficial (independentemente do jogador que contribuiu no caso dos assentos de grupo ou da reunião de operações). Se possível, o jogador que comprar a carta não deve ser o que colocou o dado de oficial. Mantenha o verso da carta oculto. Se os critérios de ativação da carta forem atendidos, leia a carta em voz alta e apresente as opções para o jogador que a ativou (mas não os efeitos dessas opções). Algumas cartas têm opções que são apresentadas para todos os jogadores. No caso de múltiplos oficiais colocados no mesmo turno, avalie o gatilho da carta de encruzilhada em relação a todos os oficiais colocados. Se mais de um oficial for ativar a carta, ela é ativada pelo oficial controlado pelo jogador mais próximo do jogador ativo no sentido horário (a partir do jogador ativo). Quando uma opção for escolhida, revele os efeitos. Quando os efeitos forem realizados, a carta é removida do jogo (pelo restante da campanha). PASSANDO Quando um jogador não tiver mais tripulantes em seu quartel, ele deve passar a vez. Quando todos os jogadores tiverem que passar, a fase 'Turnos dos Jogadores' da rodada termina. 4. FALHA DO SISTEMA Cartas de tarefas críticas que não tiverem sido completadas aplicam agora seus efeitos de falha do sistema. Degrade os sistemas afetados movendo seus indicadores de status para a direita pelo número de níveis indicado. Se o movimento do indicador de status ultrapassar a posição crítica, aplique o efeito listado na posição crítica mais uma vez para cada nível que exceder 'crítico'. 5. RECUPERAR A TRIPULAÇÃO Todos os jogadores recuperam seus dados de tripulante, começando pela Sala de Recuperação, e posteriormente de outros locais da nave ou cartas. Dados de oficial e colonos são colocados no alojamento da tripulação da sua cartela de quartel. Dados de robô (a menos que sejam parte do Quartel de Robótica) são devolvidos para o suprimento. 6. ATUALIZAR O STATUS Removam quaisquer marcadores de desabilitado dos locais da nave. Limpem a fila de tarefas críticas, devolvendo as cartas viradas para cima para o fundo do baralho de tarefas críticas. Usem marcadores de falha para cobrir quaisquer assentos nas divisões com status degradado que tenham um número de pontos igual ou menor que o indicador de status atual. 7. FIM DA RODADA Quaisquer efeitos de jogo que ocorram no final de uma rodada acontecem agora. Isso muitas vezes inclui efeitos de avanço da trama que devem se seguir a quaisquer outros efeitos. Depois desses efeitos, se o marcador de rodada atual estiver no marcador de rodada final, vão para 'Fim do Episódio'. Caso contrário, avancem o marcador de rodada atual uma casa e voltem para a fase 1."}

DOCUMENT21 = {
    "Título": "FIM DO EPISÓDIO",
    "Conteúdo": "Realizem os seguintes passos no fim de um episódio. 1. Registrem o Mérito 2. Recompensas em Estrelas de Oficial 3. Indicadores de Status em Crítico 4. Registrem o Valor Atual de / 5. Adicionem as Cartas de Relacionamento da Tripulação 6. Preparem o Próximo Episódio 1. REGISTREM O MÉRITO Todo jogador que tenha cartas de tarefa de operações na mão deduz a penalidade de mérito da carta do seu total de pontos de mérito. Em seguida, usem a seção de notas do diário de bordo para registrar a pontuação de mérito média de todos os jogadores. (Determinem a média somando as pontuações dos jogadores e dividindo pelo número de jogadores). 2. RECOMPENSAS DE OFICIAL Dê 1 de recompensa a cada jogador por cada conjunto completo de 25 que adquiriram (o jogador que completar um episódio com 56 é recompensado com 2 , por exemplo). Qualquer jogador que tenha conseguido 50+ pontos de mérito sobe de posto e registra isso embaixo do nome do seu oficial no diário de bordo. Qualquer jogador que tenha marcado menos de 50 pontos de mérito sublinha seu posto atual no diário de bordo. Se essa for a terceira vez que o posto é sublinhado, o oficial sobe de posto. Cada jogador determina para quais recompensas em estrelas de oficial ele se qualifica. Elas são encontradas nas cartas de objetivo do episódio e de objetivo pessoal. Quando o número de estrelas conquistadas for determinado, cada jogador pode então gastar suas estrelas de oficial para adquirir até 2 novos privilégios de oficial. Quando adquire um novo privilégio de oficial, o jogador pode, primeiro, descartar qualquer número dos seus privilégios de oficial atuais. Reduza o custo do novo privilégio em metade do valor em estrelas (arredondado para baixo) de cada privilégio descartado. Um jogador pode ter um número máximo de privilégios igual ao nível do seu posto atual (todos os jogadores começam no nível de posto 1, Alferes, com um espaço disponível para privilégios de oficial). Um jogador não pode adquirir um novo privilégio se já estiver no seu máximo, a menos que descarte primeiro um privilégio, conforme descrito no parágrafo acima. Um oficial não pode ter mais do que 2 cópias do mesmo privilégio de oficial. Depois de adquirir novos privilégios de oficial, cada jogador usa a seção de notas do diário de bordo para registrar quantas estrelas restaram. Essas estrelas são mantidas e podem ser usadas no final de episódios futuros. 3. INDICADORES DE STATUS EM CRÍTICO Escolham por voto popular um local da nave dentro da divisão do sistema crítico (por exemplo, se o sistema de computação estiver crítico, uma possível opção é o Laboratório Científico, que pertence à divisão de computação). Anotem o nome do local escolhido na seção 'Notas' do Diário de Bordo. Se vocês escolherem o mesmo lugar mais de uma vez, anotem o número de vezes ao lado do nome (por exemplo, 'Laboratório Científico x2'). Durante a preparação de futuros episódios, coloquem um no primeiro assento disponível de cada local listado no Diário de Bordo. Se houver um número ao lado do nome, peguem essa quantidade de e distribuam uma em cada assento. Um local não pode ter todos os assentos preenchidos logo no início do jogo. 4. REGISTREM O VALOR ATUAL DE Verifiquem o valor atual de / / na Trilha / e registrem esse valor no Diário de Bordo, na seção 'Relatório do Episódio”, ao lado do episódio que vocês acabaram de jogar. 5. ADICIONEM AS CARTAS DE RELACIONAMENTO DA TRIPULAÇÃO Adicionem as cartas listadas na seção 'Registro da Tripulação' do Diário de Bordo ao baralho de encruzilhada. Risquem as entradas de cartas no Registro da Tripulação depois de fazer isso. 6. PREPAREM O PRÓXIMO EPISÓDIO Se este não for o último episódio, separem o diário de bordo, locais e cartas de regras que estão em jogo para o próximo episódio. Guardem os privilégios de oficial e cartas de tripulação de cada jogador para usar no próximo episódio. Se um jogador tiver uma carta de encruzilhada que diz 'mantenha esta carta', separe também essa carta para o próximo episódio."}

DOCUMENT22 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 1",
    "Conteúdo": "Os tópicos a seguir são apresentados em ordem alfabética, todos com uma descrição mais detalhada das regras correspondentes. Os elementos de jogo que podem ser introduzidos durante a história têm suas próprias cartas de regras para referência. ASSENTO ANTERIOR Alguns efeitos de jogo se referem a um dado em relação ao seu assento anterior. Os assentos são ordenados do menor número de pontos para o maior número de pontos. Exemplo: O assento anterior ao assento com 3 pontos é o assento com 2 pontos. ASSENTOS DE GRUPO Assentos de grupo são indicados por um bloco de assentos conectados. Quando colocar um ou mais dos seus tripulantes em um assento de grupo, o jogador ativo pode pedir que outros jogadores contribuam com tripulantes. Se outro jogador contribuir com tripulantes, ele também pode ajudar com recursos do seu quartel, jogando cartas de arquivo e ativando cartas de esquema ou privilégios de oficial para satisfazer os requerimentos do assento de grupo. Todos os assentos devem ser ocupados e qualquer custo ligado aos assentos de grupo (por exemplo, fichas de recurso para uma tarefa crítica) deve ser pago simultaneamente. REGRAS DE COLOCAÇÃO Um bloco de assentos de grupo muitas vezes terá uma regra de relacionamento para os valores dos dados colocados nesse bloco. Um dado de valor 4 ou maior deve ser colocado nos assentos da esquerda e da direita. Um dado de valor 2 ou menor deve ser colocado no assento do meio. O valor do dado no assento da direita deve ser exatamente 1 a mais que o valor do dado colocado no assento do meio, que deve ser exatamente 1 a mais que o valor do dado colocado no primeiro assento. Por exemplo: Um 1, 2 e 3 ou um 4, 5 e 6 poderiam ser colocados aqui. Os dados colocados aqui devem todos ter o mesmo valor. O valor combinado dos dados colocados nos assentos da esquerda e do meio deve ser menor que o valor do dado colocado no assento da direita. ROBÔS Robôs são incansáveis, o que lhes dá a habilidade especial de preencher duas posições em um assento de grupo ao mesmo tempo. Nesse caso, o valor do dado de robô é divido o mais igualmente possível para seguir as regras de colocação (por exemplo, um dado de robô com valor de 11 ocupando duas posições em um bloco de assentos de grupo, representa na verdade os valores 5 e 6). CARTAS DE ARQUIVO Cartas de arquivo ficam na mão dos jogadores, juntamente com suas cartas de tarefa de operações não completadas. Não há limite para o número de cartas de arquivo na mão do jogador. A qualquer momento durante o turno de um jogador, mesmo entre ações em um local, ele pode jogar qualquer número de cartas de arquivo para ativar seus efeitos. Uma vez jogada, a carta de arquivo é devolvida para o fundo do baralho de arquivos, virada para cima. Quando a última carta de arquivo virada para baixo for comprada, embaralhe as cartas viradas para cima e coloque o baralho virado para baixo no seu tabuleiro. Quando um jogador procurar no baralho de arquivos, ele pode procurar nas cartas viradas para baixo e para cima. Quando instruído a embaralhar o baralho de arquivos, vire todas as cartas para baixo e embaralhe-as. CARTAS DE ENCRUZILHADA Uma carta de encruzilhada é comprada no final de todo turno em que um dado de oficial foi colocado. Se possível, o jogador que comprar a carta de encruzilhada deve ser um que não tenha colocado um dos dados de oficial. Mantenha o verso da carta oculto. No evento improvável de que o baralho de encruzilhada esteja vazio, pule esta etapa. GATILHO Os critérios de gatilho (texto em itálico e negrito) são avaliados para determinar se a carta tem efeito. Nesse caso, a narrativa da carta deve ser lida e as opções serão apresentadas ao(s) jogador(es) indicado(s). Os efeitos mecânicos das opções listadas não são lidos até depois de a escolha ser feita. Realizem o máximo de efeitos possível. Se a carta não tiver sido ativada, devolva-a virada para BAIXO para o fundo do baralho. No caso de múltiplos oficiais colocados no mesmo turno, avalie o gatilho da carta de encruzilhada em relação a todos os oficiais recém-colocados. Se mais de um oficial puder ativar a carta, ela é ativada pelo oficial controlado pelo jogador mais próximo do jogador ativo no sentido horário (a partir do jogador ativo). CARTAS DE ESQUEMA Cartas de esquema recebidas são colocadas na cartela de quartel do jogador. Quando (e apenas quando) uma nova carta de esquema for obtida, um jogador pode remover quaisquer cartas já posicionadas e reconfigurar suas opções de esquemas. Se o baralho de esquemas acabar, embaralhe as cartas viradas para cima no fundo para formar um novo baralho. Quando um jogador procurar no baralho de cartas de esquema, ele pode procurar nas cartas viradas para baixo e para cima. Quando instruído a embaralhar o baralho de cartas de esquema, vire todas as cartas para baixo e embaralhe-as. Cartas de esquema têm efeitos contínuos que beneficiam um jogador de diversas formas. Qualquer carta de esquema aplicável é ativada quando a condição de efeito descrita é atendida. Um quartel não pode ter duas cartas de esquema com o mesmo nome posicionadas, mas a segunda pode ser usada como foco. FOCO Além de posicionar uma carta de esquema em um espaço vazio, uma única carta de esquema pode ser colocada virada para baixo atrás de outra carta no mesmo espaço. Nessa configuração, a carta de esquema virada para cima recebe foco. Uma carta de esquema com foco substitui o texto indicado no seu efeito pelo texto listado na descrição do foco."}

DOCUMENT23 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 2",
    "Conteúdo": "LIMITE DE ESPAÇOS Cada cartela de quartel pode ter até 2 esquemas. Quando um jogador tiver mais cartas do que podem ser posicionadas ou usadas para foco, ele deve descartar as cartas excedentes viradas para cima no fundo do baralho de esquemas. CARTAS DE OBJETIVO DE EPISÓDIO O livro da trama do episódio definirá as cartas de objetivo de episódio que devem ser incluídas na preparação. As cartas de objetivo de episódio descrevem métodos para ganhar estrelas de oficial. As estrelas de oficial conquistadas são registradas nas próprias cartas de objetivo de episódio ou em outros elementos de jogo mencionados nos objetivos. Algumas cartas de objetivo de episódio têm lados de sucesso e fracasso. Essas cartas começam o episódio com o lado do sucesso virado para cima e têm instruções sobre quando elas devem ser viradas para o lado do fracasso. O lado do fracasso pode ter uma recompensa menor ou nenhuma recompensa. As estrelas conquistadas são determinadas nas etapas de fim do episódio. CARTAS DE OBJETIVO PESSOAL Se o objetivo de episódio “Objetivos Pessoais” estiver em jogo nesse episódio, cada jogador recebe três cartas de objetivo pessoal durante a preparação: uma correspondente ao seu quartel, um plano A e um plano B. Essas cartas oferecem oportunidades adicionais para o jogador conquistar estrelas para seu oficial. Todas as cartas de objetivo pessoal podem ser completadas em um episódio. Objetivo Pessoal: Cartas de Plano A e Plano B, quando adquiridas, são informações privadas. Quando os critérios de uma cartas de objetivo pessoal são atendidos, ela é revelada para os outros jogadores e colocada virada para cima ao lado da sua cartela de quartel. CARTAS DE REGRAS Cartas de regras proporcionam informações de referência adicionais ou são incluídas quando novos elementos de jogo são introduzidos. Essas cartas podem ser colocadas perto dos seus elementos de jogo durante a preparação até que os jogadores tenham uma boa compreensão da sua função. CARTAS DE TAREFA CRÍTICA Para completar uma tarefa crítica, todos os seus assentos de grupo devem ser preenchidos (de acordo com as regras de colocação indicadas) e quaisquer fichas de recurso necessárias pagas a partir do Depósito da Nave, dos quartéis dos jogadores ou da própria carta. Todos os requerimentos para completar a tarefa devem ser atendidos simultaneamente, e não como contribuições parciais ao longo de vários turnos (ou seja, um jogador não pode colocar um tripulante em um assento de grupo, esperando que os assentos ou recursos faltantes sejam colocados em outro turno). Um jogador contribuiu com uma tarefa crítica se tiver colocado um dado de tripulante. Os jogadores contribuintes podem também fornecer fichas de recurso, jogar cartas de arquivo ou ativar esquemas ou privilégios de oficial para ajudar a completar a tarefa crítica. Uma tarefa crítica completada permanece completada mesmo se dados ou fichas de recurso forem tiradas dela. RECOMPENSAS EM PONTOS DE MÉRITO Quando a tarefa crítica é completada, todos os quartéis que contribuíram recebem a recompensa em pontos de mérito. Um quartel que tenha contribuído com mais de um dado de tripulante não recebe pontos de mérito adicionais. RELACIONAMENTOS DE ASSENTO Apenas certos valores de dados de tripulante podem ser usados para contribuir para uma tarefa crítica. Cada assento de grupo informa aos jogadores quais valores de dado de tripulante podem ser usados. DIVISÃO Cada carta de tarefa crítica é parte da sua divisão listada. Isso é importante para ativar as cartas de encruzilhada, além dos totais de tripulantes localizados em uma divisão específica. CARTAS DE TAREFA DE OPERAÇÕES Cartas de tarefa de operações são recebidas no começo do episódio, ou ao participar de uma reunião de operações no local da nave “Operações”. Se esse baralho acabar, as cartas de tarefa de operações viradas para cima devem ser embaralhadas para formar um novo baralho. Quando um jogador procurar no baralho de tarefas de operações, ele pode procurar nas cartas viradas para baixo e para cima. Quando instruído a embaralhar o baralho de tarefas de operações, vire todas as cartas para baixo e embaralhe-as. Essas cartas de tarefa são particulares de cada jogador e dão uma recompensa em pontos de mérito ao serem concluídas. Para completar uma tarefa de operações, o jogador deve colocar um dado de tripulante no centro definido pela tarefa, realizar a ação do centro que permite completar uma tarefa de operações e pagar o custo listado em fichas de recursos. Note que cada ação do centro permite completar apenas uma tarefa de operações. Quando uma carta de tarefa de operações for completada, o jogador recebe os pontos de mérito listados e coloca a carta completada virada para cima no fundo do baralho de tarefas de operações. Em alguns casos, a carta de tarefa de operações também inclui um efeito de jogo que é ativado quando ela é completada. LIMITE DA MÃO: Cartas de tarefa de operações ficam na mão dos jogadores, junto de suas cartas de arquivo. Um jogador não pode ter mais de 5 cartas de tarefa de operações na mão em nenhum momento. Se um jogador tiver 5 cartas de tarefa de operações, ele não pode receber outra. FIM DO EPISÓDIO Todas as cartas de tarefa de operações que continuem na mão do jogador no final de um episódio valem uma penalidade que subtrai pontos de mérito do total desse jogador. CARTAS DE TRIPULANTE Todos os jogadores recebem uma carta de tripulante aleatória antes do primeiro episódio de uma campanha. Essa carta identifica um tripulante com quem o jogador tem um relacionamento (um amigo próximo, aprendiz, etc.). Algumas cartas de encruzilhada serão disparadas para um jogador com base em qual carta de tripulante ele tem. CARTELAS DE QUARTEL Todos os jogadores recebem uma cartela de quartel aleatória no começo de cada episódio. É provável que o quartel que o jogador comanda mude de um episódio para outro, encorajando estratégias de jogo diferentes. ALOJAMENTO DA TRIPULAÇÃO Tripulantes que não estejam colocados devem ser armazenados na área “alojamento da tripulação” da cartela de quartel."}

DOCUMENT24 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 3",
    "Conteúdo": "DEPÓSITO DE RECURSOS Fichas de recursos coletadas devem ser armazenadas na área “depósito de recursos” da cartela de quartel. Todos os quartéis têm o mesmo limite de armazenamento de 15 fichas de cada tipo de recurso. ESPAÇOS DE ESQUEMA: Cada espaço de esquema pode conter uma carta de esquema virada para cima e uma segunda carta de esquema virada para baixo sob a primeira, como foco. HABILIDADES ÚNICAS DOS QUARTÉIS Cada quartel tem uma habilidade única. O Quartel de Ciências tem um Laboratório Científico Particular. Esse assento está disponível apenas para o jogador que o controla. Ele conta como um laboratório, mas não é parte de nenhuma divisão. Quando um dado é colocado nesse laboratório particular, além de conseguir dados, o jogador pode pagar 3 dados para ativar a ação opcional “Analisar”. O Quartel de Engenharia tem um Laboratório de Reciclagem Particular. Esse assento está disponível apenas para o jogador que o controla. Ele conta como um laboratório, mas não é parte de nenhuma divisão. Quando um dado é colocado nesse laboratório particular, além de conseguir peças, o jogador pode pagar 3 peças para ativar a ação opcional “Projetar”. O Quartel de Biociências tem um Laboratório Químico Particular. Esse assento está disponível apenas para o jogador que o controla. Ele conta como um laboratório, mas não é parte de nenhuma divisão. Quando um dado é colocado nesse laboratório particular, além de conseguir substâncias químicas, o jogador pode pagar 3 substâncias químicas para ativar a ação opcional “Reviver”. O Quartel de Robótica começa cada rodada com seu dado de robô no quartel, substituindo um dos seus dados de colono. Além disso, o Quartel de Robótica tem um assento de “Reprogramação” que permite ao jogador mandar o dado de robô de qualquer jogador de volta para o quartel dele (permitindo que ele o use de novo em um turno subsequente). Esse assento está disponível apenas para o jogador que o controla. Ele não é parte de nenhuma divisão. CHEFE DE OPERAÇÕES O jogador com a insígnia de chefe de operações tem a habilidade de determinar o resultado dos empates nas votações quando esses acontecem. No começo de cada rodada, o jogador com a insígnia de chefe de operações será o jogador na primeira posição. COMEÇAR UMA NOVA PARTIDA. No fim da sua história, você poderá começar uma nova partida para criar uma nova história. Para fazer isso, separe os elementos de jogo pelas suas identificações e devolva-os em ordem para seus pacotes ou envelopes (em alguns casos, a carta de regras do elemento vai ajudá-lo com isso). Elementos de jogo sem uma identificação são “abertos” no começo de uma nova história. DADOS DE TRIPULANTE Há três tipos de dados de tripulante: oficial, colono e robô. Os termos tripulante, dado/dados e dados de tripulante são intercambiáveis. DADOS DE OFICIAL O dado de oficial de um quartel representa o personagem do jogador na história. É possível que as cartas de encruzilhada sejam ativadas quando ele é colocado. Os dados de oficial têm 8 lados (D8). DADOS DE COLONO Os dados de colono de um quartel representam a maior parte da tripulação da nave e sua força de trabalho primária. Cada um deles está enfrentando seus próprios problemas, e algumas dessas histórias serão exploradas nas cartas de encruzilhada. Os dados de colono têm 6 lados (D6). DADOS DE ROBÔ O dado de robô de um quartel representa um robô assistente programável da tripulação da nave. Eles são requisitados no local “Robótica” ou são parte inerente do Quartel de Robótica. O fato de serem incansáveis os torna especialmente úteis quando há assentos de grupo envolvidos, já que podem cobrir duas posições dividindo seu valor pela metade o mais igualmente possível. Os dados de robô têm 12 lados (D12). DEPÓSITO DA NAVE O Depósito da Nave é parte da divisão de operações. Fichas de recurso no Depósito da Nave podem ser usadas por qualquer jogador, mas apenas para completar tarefas críticas. DESEMPATE POR PONTOS DE MÉRITO Um empate entre jogadores com marcadores de pontos de mérito no mesmo valor é decidido em favor do jogador que tenha atingido, ou excedido, esse valor primeiro. Quando diversos marcadores de pontos de mérito estiverem empilhados no mesmo valor, o desempate é decidido em favor do marcador que está por baixo (e considera-se que ele tem um valor maior de pontos de mérito). Para ajudar a acompanhar as posições corretas dos marcadores de pontos de mérito, use estas regras: Quando mover um marcador de ponto de mérito na direção positiva, coloque esse marcador em cima de qualquer marcador de pontos de mérito que já esteja no destino. Se mais de um marcador estiver sendo movido na direção positiva ao mesmo tempo, mova-os em ordem do maior para o menor valor de pontos de mérito (obedecendo às condições de desempate para marcadores no mesmo valor). Quando mover um marcador de ponto de mérito na direção negativa, coloque o marcador embaixo de qualquer marcador de pontos de mérito que já esteja no destino. Se mais de um marcador estiver sendo movido na direção negativa ao mesmo tempo, mova-os em ordem do menor para o maior valor de pontos de mérito (obedecendo às condições de desempate para marcadores no mesmo valor). DIÁRIO DE BORDO O Diário de Bordo pode ser usado para registrar o progresso de toda a história. Ele inclui espaço para os jogadores batizarem sua nave e tomarem notas, com outras áreas reservadas exclusivamente para efeitos de jogo. CONDIÇÃO Se o marcador de status do sistema da nave estiver na posição crítica ( +1), marque uma caixa. Se o marcador de status ultrapassar o “crítico”, marque mais uma caixa para cada nível excedido. Se todas as caixas forem marcadas, a carta B9 é tirada do pacote B. REGISTRO DA TRIPULAÇÃO Esse espaço é usado para registrar escolhas feitas durante o jogo, muitas vezes devido a opções das cartas de encruzilhada. RELATÓRIO DO EPISÓDIO Essa área é usada para registrar o Melhor Oficial e estado final de cada episódio. "}

DOCUMENT25 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 4",
    "Conteúdo": "ESTRELAS DE OFICIAL Conquistar estrelas de oficial é o principal objetivo de todos os jogadores ao longo da história. Essas estrelas são a moeda com a qual os jogadores compram privilégios de oficial. FASE DE DEGRADAÇÃO Uma penalidade que move um indicador de status uma posição para a direita. Cada nível de degradação muda a cor do status da divisão afetada. FICHAS Fichas são usadas no jogo como recursos ou gastas para ativar efeitos de jogo. FICHAS DE RECURSO Fichas de dados, peças e produtos químicos são a moeda principal do jogo em relação a recursos, e são necessárias para completar a maioria das tarefas críticas e todas as tarefas de operações. Para pagar um custo em recursos, os jogadores descartam as fichas de recurso de seus quartéis para o suprimento. Além de usar fichas de recurso para completar tarefas, cada tipo de recurso tem um uso adicional. DADOS Antes de comprar qualquer carta para as ações “Arquivo” ou “Esquema”, você pode gastar até 2 para comprar o mesmo número de cartas de ou adicionais. Nota: isso permite apenas que você compre cartas adicionais para selecionar. Você fica com apenas uma carta e coloca as demais viradas para cima no fundo do baralho apropriado. PEÇA No seu turno, ou quando estiver contribuindo para um assento de grupo, você pode gastar 2 para ajustar o valor de um robô em seu quartel ou naquele assento de grupo em até 2 (em qualquer direção dentro dos limites naturais do dado). PRODUTO QUÍMICO No seu turno, ou quando estiver contribuindo para um assento de grupo, você pode gastar 2 para mudar o valor de um dado de oficial ou colono em seu quartel ou naquele assento de grupo para qualquer valor desejado. INSÍGNIA: CHEFE DE OPERAÇÕES A insígnia de chefe de operações é entregue aleatoriamente a um jogador no começo do episódio, e pode depois ser obtida por outro que seja o primeiro a colocar um oficial ou colono no local “Operações” para iniciar uma reunião. Quem estiver com a insígnia de chefe de operações no momento é o primeiro a agir em cada rodada. Esse jogador também decide empates nas votações. JOGADOR ATIVO O jogador que está realizando seu turno no momento é chamado de 'jogador ativo'. LIMITES DE RECURSOS O Depósito da Nave e todos os quartéis dos jogadores têm um limite de 15 fichas de recurso de cada tipo (ou seja, 15 dados, 15 peças, 15 produtos químicos). Quando um quartel recebe fichas de recurso de um laboratório, o limite de recursos é ignorado temporariamente para permitir que o jogador realize a ação Doar. Qualquer excesso de fichas deve ser descartado no suprimento. O limite de recursos do Depósito da Nave nunca pode ser excedido, impedindo assim a ação Doar se a quantidade doada fizer esse limite ser excedido. LIVRO DA TRAMA A narrativa de cada episódio avança por meio do livro da trama. Quando o livro da trama instruir para avançar para uma nova seção, abra a página apropriada e leia o conteúdo da seção em voz alta. O livro da trama informará sobre quando pular o texto em uma página ou avançar para uma nova página e seção. Não vire uma página a menos que receba instruções para isso. Enquanto estiver avançando pelo livro da trama, você pode ser instruído a pular ou avançar para uma nova seção. Se receber essa instrução, não leia ou execute nenhuma ação sobre o texto entre a seção atual e a seção indicada. Você deve pular diretamente para a seção indicada e continuar dali. Na conclusão de um episódio, o livro da trama informará onde colocar o marcador de página para o próximo episódio. Muitas vezes você também será instruído a adicionar novos elementos de jogo, que terão efeito nos próximos episódios. LOCAIS DA NAVE Locais da nave têm assentos para a tripulação, proporcionando ações para os jogadores que escolherem colocar tripulantes ali. As ações listadas em itálico são opcionais. DIVISÃO Cada local da nave é parte da divisão listada. Isso é importante para ativar as cartas de encruzilhada, além dos totais de tripulantes localizados em uma divisão específica. LOCAL DA NAVE 'CENTRO DE DADOS' O local 'Centro de Dados' é parte da divisão de computação. ARQUIVO Compre as 2 primeiras cartas do baralho de arquivos e mantenha 1. Se qualquer outro efeito permitir que você compre cartas adicionais, mantenha apenas 1 das cartas compradas. TERMINAL Uma ação opcional para completar uma tarefa de operações do Centro de Dados. Para completar a tarefa, você deve também descartar o custo em fichas de recursos da tarefa do seu quartel. LOCAL DA NAVE “CENTRO DE MANUFATURA” O local “Centro de Manufatura” é parte da divisão de energia. ESQUEMAS Compre as 2 primeiras cartas do baralho de esquemas e mantenha 1. Se qualquer outro efeito permitir que você compre cartas adicionais, mantenha apenas 1 das cartas compradas. Depois de decidir como vai posicionar suas cartas de esquema, você pode descartar quaisquer cartas de esquema que não quiser manter ou não puder posicionar/focar no fundo do baralho de esquemas, viradas para cima. BANCADA DE TRABALHO Uma ação opcional para completar uma tarefa de operações do Centro de Manufatura. Para completar a tarefa, você deve também descartar o custo em fichas de recursos da tarefa do seu quartel. LOCAL DA NAVE “CENTRO MÉDICO” O local “Centro Médico” é parte da divisão da biosfera. ANIMAÇÃO SUSPENSA Coloque seu marcador de tripulante em hibernação na Sala de Recuperação OU troque seu marcador de tripulante em hibernação na Sala de Recuperação por um dos seus dados de colono do suprimento.Quando todos os dados de colono forem tirados do suprimento, pule a ação “Animação Suspensa” quando colocar tripulantes no Centro Médico."}

DOCUMENT26 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 5",
    "Conteúdo": "EXPERIMENTO Uma ação opcional para completar uma tarefa de operações no Centro Médico. Para completar a tarefa, você deve também descartar o custo em fichas de recursos da tarefa do seu quartel. LOCAL DA NAVE “LABORATÓRIO CIENTÍFICO” O Laboratório Científico é parte da divisão de computação. DADOS Receba fichas de dados para seu quartel com base no assento ocupado. O símbolo # representa o valor do dado do tripulante colocado, e o cálculo total é arredondado para cima. Depois que você realizar ou pular a ação Doar, descarte quaisquer fichas de dados que excedam o limite do seu quartel. DOAR Uma ação opcional para doar 3 ou 6 fichas de dados do seu quartel para o Depósito da Nave para ganhar 1 ou 2 pontos de mérito, respectivamente. Você não pode doar se isso fizer com que o Depósito da Nave exceda seu limite de recursos. LOCAL DA NAVE “LABORATÓRIO DE RECICLAGEM” O local “Laboratório de Reciclagem” é parte da divisão de energia. REGRA DE COLOCAÇÃO Quando um dado for colocado aqui, seu valor deve ser igual ou maior que o do dado no assento anterior. PEÇAS Receba fichas de peça para seu quartel com base no assento ocupado. Depois que você realizar ou pular a ação “Doar”, descarte quaisquer fichas de peça que excedam o limite do seu quartel. DOAR Uma ação opcional para doar 3 ou 6 fichas de peça do seu quartel para o Depósito da Nave para ganhar 1 ou 2 pontos de mérito, respectivamente. Você não pode doar se isso fizer com que o Depósito da Nave exceda seu limite de recursos. LOCAL DA NAVE “LABORATÓRIO QUÍMICO” O local “Laboratório Químico” é parte da divisão da biosfera. PRODUTOS QUÍMICOS Receba fichas de produto químico para seu quartel com base no assento ocupado. Todos os outros tripulantes atualmente no laboratório químico recebem 1 ficha de produto químico para seus quartéis. Depois que você realizar ou pular a ação “Doar”, descarte quaisquer fichas de produto químico que excedam o limite do seu quartel. DOAR Uma ação opcional para doar 3 ou 6 fichas de produto químico do seu quartel para o Depósito da Nave para ganhar 1 ou 2 pontos de mérito, respectivamente. Você não pode doar se isso fizer com que o Depósito da Nave exceda seu limite de recursos. LOCAL DA NAVE “OPERAÇÕES” O local “Operações” é parte da divisão de operações. Apenas oficiais e colonos podem ser colocados em Operações, não os tripulantes robôs. CHEFE DE OPERAÇÕES O jogador ativo que estiver colocando seus dados de colono ou oficial deve escolher o assento do chefe de operações, recebendo a insígnia de chefe de operações. REUNIÃO DE OPERAÇÕES Em sentido horário a partir do jogador ativo, cada jogador pode contribuir imediatamente com um dado de oficial ou colono do seu quartel para se juntar à reunião. Depois que todos os jogadores tiverem a oportunidade de se juntar à reunião, comprem 2x + 1 cartas de tarefas de operações do baralho (em que x é o número de tripulantes em Operações). Se a última carta virada para baixo do baralho de tarefas de operações for comprada, embaralhem as cartas viradas para cima no fundo e criem um novo baralho. Passem a seleção de cartas de tarefa de operações para o jogador com o tripulante de maior valor colocado em Operações (o critério de desempate é qual dado foi colocado primeiro). A seleção de cartas será passada pela mesa duas vezes no sentido horário para todos os jogadores que estejam participando da reunião. Durante a primeira passagem, cada jogador deve escolher uma carta da seleção de cartas de tarefa de operações. Durante a segunda passagem, cada jogador pode escolher uma carta da seleção. Nota: Um jogador nunca pode ter mais de 5 cartas de tarefa de operações na mão. Se tiver que pegar uma nova carta e já tiver 5, ele pode examinar a seleção, mas não deve pegar uma carta. Devolvam as cartas não selecionadas viradas para cima para o fundo do baralho de tarefas de operações. LOCAL DA NAVE “ROBÓTICA” O local “Robótica” é parte da divisão de computação. TRIPULANTES ROBÔ Receba seu dado de tripulante robô do suprimento (você não pode colocar seu tripulante aqui se o robô não estiver no suprimento). O dado de robô é rolado imediatamente e colocado na cartela do seu quartel. Se o resultado do robô for 1, você pode mudar o resultado para qualquer valor desejado. Tripulantes robô não podem ser colocados em Operações. INCANSÁVEL Um dado de robô pode preencher duas posições em um assento de grupo ao mesmo tempo. Nesse caso, o valor do dado de robô é divido o mais igualmente possível para seguir as regras de colocação (por exemplo, um dado de robô com valor de 11 ocupando duas posições em um bloco de assentos de grupo, representa na verdade os valores 5 e 6). MARCADORES Marcadores são usados no jogo para registrar informações. MARCADORES DE PONTOS DE MÉRITO Cada quartel em um episódio tem um marcador de pontos de mérito para registrar os pontos de mérito conquistados naquele episódio. MARCADORES DE 50 / 100 PONTOS DE MÉRITO Se os pontos de mérito de um quartel atingirem 50, o jogador que o controla vira o marcador de pontos de mérito para o lado “50” e o coloca no “0”. MARCADORES DE TRIPULANTE EM HIBERNAÇÃO Cada quartel em um episódio começa com seu marcador de tripulante em hibernação na Sala de Recuperação. Esse marcador é usado pela ação “Animação Suspensa” do Centro Médico como um processo em duas etapas para reviver dados de colono do suprimento para serem usados nos quartéis. MARCADORES DE SUCESSO Marcadores de sucesso são mais frequentemente usados para registrar o progresso da trama, mas também podem ser usados como lembrete para outros elementos de jogo (por exemplo, o número de vezes que o jogador do Quartel de Robótica realiza a ação “Doar”)."}

DOCUMENT27 = {
    "Título": "SEÇÃO DE REFERÊNCIA DAS REGRAS - Parte 6",
    "Conteúdo": "MARCADORES DE FALHA Marcadores de falha são mais frequentemente usados para cobrir assentos dentro de uma divisão conforme ela se degrada, ou para registrar o número de vezes que a trama não avançou. Um assento coberto por um marcador de falha não pode ser ocupado por tripulantes. Marcadores de falha cobrindo assentos nos locais da nave não são removidos no final de uma rodada. MARCADORES DE DESABILITADO Marcadores de desabilitado são mais frequentemente usados para cobrir assentos temporariamente. Um assento coberto por um marcador de desabilitado não pode ser ocupado por tripulantes, mas marcadores de desabilitado que estejam cobrindo assentos em locais da nave são removidos no fim de uma rodada. MARCADORES DE RODADA ATUAL / RODADA FINAL O marcador de rodada atual começa o episódio na posição 1 da trilha de rodada. O marcador de rodada final pode ser definido na preparação de um episódio ou colocado posteriormente pela trama. Quando uma rodada termina e os marcadores de rodada atual e rodada final estão no mesmo valor, acontecem as etapas de fim de episódio. MARCADOR DE AVANÇO DA TRAMA O marcado de avanço da trama é colocado após a preparação do episódio ou seguindo instruções especiais de preparação. Ele é um lembrete para os jogadores de que o objetivo atual da trama deve ser completado até o fim daquela rodada para que a trama avance com sucesso sem um efeito de contratempo. OFICIAL EM DESTAQUE Quando um jogador completa o objetivo de episódio “Melhor Oficial”, parte da sua recompensa é ser o “Oficial em Destaque” do próximo episódio. Ter o Oficial em Destaque permite ao jogador pedir que uma segunda carta de encruzilhada seja comprada se a primeira carta não for ativada no final do turno em que ele colocou seu oficial. POSTO DE OFICIAL Todos os jogadores começam o jogo com seu oficial no posto 1, Alferes. Quando o objetivo de episódio “Desempenho do Oficial” estiver em jogo, conquistar 50 ou mais durante um episódio proporcionará ao oficial do jogador uma promoção de 1 posto. O oficial pode avançar pelos postos de Tenente, Tenente Comandante, Comandante e, finalmente, o posto máximo de Capitão, número 5. PRIVILÉGIOS DE OFICIAL O número do posto do oficial de um jogador é o número máximo de privilégios que ele pode ter ao mesmo tempo. Os próprios privilégios de oficial também têm requerimentos de posto que devem ser atendidos para adquirir o privilégio. VOTAÇÃO O número do posto de oficial de um jogador é o número de votos que esse jogador tem em uma votação. Todos os votos do jogador são direcionados para sua decisão (por exemplo, um jogador com um oficial de posto 3 que decida votar “polegar para cima” deve votar três vezes para essa opção). PRIMEIRO ASSENTO DISPONÍVEL Ocasionalmente uma instrução dirá que algo deve ser colocado no primeiro assento disponível de um local. Isso indica o assento no local com menor número de pontos que ainda não esteja ocupado por um dado ou marcador de falha / desabilitado. PRIVILÉGIOS DE OFICIAL Um jogador pode comprar até 2 privilégios entre episódios, usando as estrelas de oficial que adquiriu. Esses privilégios são mantidos nos episódios futuros. Um jogador pode ter um número máximo de privilégios igual ao nível do seu posto atual (todos os jogadores começam no nível de posto 1, Alferes, com um espaço disponível para privilégios de oficial). Quando adquire um novo privilégio de oficial, o jogador pode, primeiro, descartar qualquer quantidade dos seus privilégios de oficial atuais. Reduza o custo do novo privilégio em metade do valor em estrelas (arredondado para baixo) de cada privilégio descartado. Um jogador não pode adquirir um novo privilégio se já estiver no seu máximo, a menos que descarte primeiro um privilégio, conforme descrito no parágrafo acima. REMOVER DO JOGO Se um elemento de jogo instruir você a removê-lo do jogo, esse elemento não aparecerá no restante da sua história. Deixe-o de lado até começar uma nova partida. TEXTO DA CARTA / LOCAL Quando o efeito de uma carta / local contradisser o livro de regras, o efeito da carta / local tem prioridade. TROCAR OU DAR Os jogadores não podem trocar ou dar quaisquer elementos de jogo uns para os outros. As únicas contribuições permitidas são quando assentos de grupo estão envolvidos, e a contribuição deve ser usada apenas para colocar tripulantes ou pagar os custos associados a esses assentos de grupo. ÚLTIMO ASSENTO DISPONÍVEL Ocasionalmente uma instrução dirá que algo deve ser colocado no último assento disponível de um local. Isso indica o assento no local com maior número de pontos que ainda não esteja ocupado por um dado ou marcador de falha / desabilitado. VOTAÇÃO Quando uma votação for necessária, os jogadores podem discutir suas opções até que uma delas receba a maioria dos votos. Se os jogadores estiverem divididos igualmente e nenhuma opção receber a maioria, o chefe de operações atual decide a votação. POSTO DE OFICIAL O número do posto de oficial de um jogador é o número de votos que esse jogador tem em uma votação. Todos os votos do jogador são direcionados para sua decisão (por exemplo, um jogador com um oficial de posto 3 que decida votar 'polegar para cima' deve votar três vezes para essa opção). TRILHA / Quando instruído, o valor atual da Trilha / somará esse número de votos à opção apropriada: Lógica ou Instinto. Quando isso ocorrer, o marcador / volta para 0"}

DOCUMENT28 = {
    "Título": "VISÃO GERAL DOS PRIVILÉGIOS DE OFICIAL",
    "Conteúdo": "INOVADOR Quando comprar cartas de 3 no Centro de Manufatura, compre 1 carta extra sem custo de . (Fique com apenas 1 carta). INVESTIGADOR Quando comprar cartas de 3 no Centro de Dados, compre 1 carta extra sem custo de . (Fique com apenas 1 carta). MOTIVADOR 3 Uma vez por episódio, você pode aumentar o valor de todos os dados de colono no seu quartel em até 3 (respeitando o valor máximo natural do dado). BIOCIENTISTA Ganhe 3 pontos de 4 adicionais quando completar uma tarefa de operações no Centro Médico. QUÍMICO Ganhe 1 ficha de 4 adicional quando colocar tripulantes em um laboratório químico. ENGENHEIRO Ganhe 3 pontos de 4 adicionais quando completar uma tarefa de operações no Centro de Manufatura. CIENTISTA 4 SUCATEIRO 4 Ganhe 3 pontos de adicionais quando completar uma tarefa de operações no Centro de Dados. Ganhe 1 ficha de adicional quando colocar tripulantes em um laboratório de reciclagem. ANALISTA Ganhe 1 ficha de 4 adicional quando colocar tripulantes em um laboratório científico. LOBO SOLITÁRIO 5 Quando uma reunião de operações for convocada, você pode pegar uma carta do topo do baralho de operações em vez de participar da reunião. ACADÊMICO 5 Quando colocar tripulantes na divisão de computação, você pode alterar seus resultados em +1 ou -1 (respeitando os valores naturais dos dados). CUIDADOR 5 Quando colocar tripulantes na divisão da biosfera, você pode alterar seus resultados em +1 ou -1 (respeitando os valores naturais dos dados). LÍDER NATURAL 5 Quando colocar tripulantes na divisão de operações, você pode somar até 2 aos seus resultados (respeitando o valor máximo natural do dado). TRABALHADOR 5 Quando colocar tripulantes na divisão de energia, você pode alterar seus resultados em +1 ou -1 (respeitando os valores naturais dos dados). CORAJOSO Ganhe 1 6 adicional quando contribuir com tripulantes para completar uma tarefa crítica. 18 ACUMULADOR 6 Ganhe 5 fichas de por episódio. uma vez HACKER Ganhe 5 fichas de por episódio. 6 uma vez CONTRABANDISTA Ganhe 5 fichas de por episódio. 6 uma vez OTIMIZADOR 6 Uma vez por episódio, você pode comprar até 2 cartas de tarefa de operações do topo do baralho, e então descartar até 2 cartas de tarefa de operações da sua mão. MODIFICADOR 6 Uma vez por episódio, depois que usar uma carta de , você pode ativar imediatamente os efeitos daquela carta novamente. MÉDICO 8 Uma vez por episódio, você pode enviar até três dados de tripulante na Sala de Recuperação para seus quartéis para serem rolados e usados novamente. DIRETOR 8 ARQUIVISTA 8 Uma vez por episódio, quando você colocar seu oficial no Centro de Dados e realizar a ação 'Arquivo', você pode, em vez disso, comprar 6 cartas de . Examine as cartas e dê a três jogadores diferentes uma carta à sua escolha para cada um; Em seguida, descarte o resto. Uma vez por episódio, você pode procurar uma carta à sua escolha no baralho de cartas de . Coloque essa carta na sua mão e embaralhe o baralho de cartas de . ARQUITETO 8 Uma vez por episódio, quando você colocar seu oficial no Centro de Manufatura e realizar a ação 'Esquema', você pode, em vez disso, comprar 6 cartas de . Examine as cartas e dê a três jogadores diferentes uma carta à sua escolha para cada um; Em seguida, descarte o resto. ADVOGADO 8 Duas vezes por episódio, quando colocar seu oficial no Centro Médico, você pode dar a um jogador uma ação 'Animação Suspensa' imediata sem colocar um dado de tripulante. RESOLVEDOR DE PROBLEMAS 8 Uma vez por episódio, reduza o custo em recursos de qualquer tarefa crítica ou de operações em 6 fichas de recurso à sua escolha. SUPERVISOR 8 Uma vez por episódio, quando você contribuir com seu oficial para um assento de grupo, você pode mudar os valores de todos os dados contribuídos para quaisquer valores desejados. PLANEJADOR 8 Uma vez por episódio, você pode procurar uma carta à sua escolha no baralho de cartas de . Posicione a carta e embaralhe o baralho de . PROVEDOR 8 Uma vez por episódio, você pode selecionar três jogadores diferentes e um tipo de recurso. Cada jogador selecionado recebe 3 recursos daquele tipo."}

DOCUMENT29 = {
    "Título": "PERGUNTAS FREQUENTES",
    "Conteúdo": "P: O que são os dados de quartel? R: Quando o jogo menciona um dado de quartel, está se referindo ao dado que não foi usado naquele quartel. P: Se duas pessoas receberem mérito ao mesmo tempo (nos assentos de grupo, por exemplo), quem move o marcador de mérito primeiro? Isso pode fazer diferença se houver um empate no final do episódio. R: O jogador ativo é o primeiro a mover o marcador, e então a pontuação segue em sentido horário. P: As cartas de encruzilhada do Gen7 funcionam do mesmo jeito do que as do Dead of Winter? R: Não, em Gen7 as cartas de encruzilhada funcionam de maneira diferente. Compra-se uma única carta de encruzilhada do topo do baralho no final de qualquer turno de jogador em que dados de oficiais foram usados. A ativação é avaliada com todos esses oficiais (se houver mais de um, comecem pelo jogador ativo e sigam em sentido horário). Se a carta não for ativada, ela vai para o fundo do baralho. P: Algumas das cartas de encruzilhada são ativadas se um jogador tem um “relacionamento” com um dos personagens em uma carta de tripulante... O que esse “relacionamento” quer dizer? R: No início de uma campanha, cada jogador recebe uma carta de tripulante aleatória, que vai ficar com o jogador durante toda aquela campanha. Esse tripulante é o personagem com quem o jogador tem um relacionamento. P: As cartas de tripulantes distribuídas aos jogadores têm que ter a mesma cor do quartel deles? R: Não, elas devem ser distribuídas aleatoriamente, e não por cores. Atenção: cartas de tripulantes não servem para representar os personagens dos jogadores, e sim para mostrar com quem cada jogador tem um relacionamento a bordo da nave. Esse relacionamento não é, necessariamente, entre membros do mesmo quartel. P: Uma carta de encruzilhada diz: “resolva se o oficial estiver” na divisão X. Se eu estiver em uma carta de tarefa que pertence àquela divisão, isso conta? R: Sim. As cartas de tarefa crítica fazem parte da divisão listada. Isso conta nas cartas de encruzilhada, assim como em algumas cartas de objetivo pessoal nas quais o jogador deve ter o maior número de tripulantes ocupando uma divisão. P: Algumas das cartas de tarefa de operações mencionam tipos de ameaça de missão. O que é isso? R: As ameaças de missão não estão presentes no Episódio 1, e mais sobre elas será revelado durante os próximos episódios. P: Se uma carta de esquema que estava em foco for descartada para abrir espaço para uma nova carta, o foco é transferido para a nova carta de esquema ou é descartado junto com a carta antiga? R: A melhor coisa sobre as cartas de esquema é que você pode reconfigurá-las. É uma construção de motores dinâmicos, então, respondendo à pergunta, quando uma carta de esquema é descartada (porque você já tem quatro cartas – ou seis, no caso de logística), reconfigure as cartas restantes da forma que desejar (espaço e foco). P: E se mais de uma pessoa quiser gastar suas estrelas para comprar o mesmo privilégio de oficial e não tiver privilégios o bastante para todos? R: Se os jogadores não chegarem em um acordo, os privilégios devem ser adquiridos um por vez, na ordem do turno, começando com o chefe de operações. P: As cartas de privilégios de oficial descartadas ficam disponíveis para outros jogadores adquirirem-nas? R: Sim. P: Como funciona o pedido de ajuda para os assentos de grupo? R: O jogador ativo refere-se ao assento de grupo que deseja ocupar e pode solicitar a ajuda de outros. Se mais de um jogador oferecer ajuda, o jogador ativo escolhe qual dos jogadores será aquele que contribuirá com dados para o assento de grupo. O jogador ativo não pode forçar nenhum outro jogador a se juntar a ele. Depois de pedir por ajuda, o jogador ativo pode escolher ocupar os lugares com seus próprios dados ou simplesmente decidir por outro assento e ignorar o assento de grupo por enquanto. Um jogador nunca deve colocar um dado em um assento de grupo com a intenção de preenchê-lo posteriormente. P: Como funcionam os assentos de grupo no Habitat Deserto e no Hub Central? R: Há dois assentos de grupo diferentes no Habitat Deserto (cada um com 2 assentos). Cada vez que um jogador ocupar um dos assentos de grupo (o que requer dois dados ou, possivelmente, um dado de robô), deve realizar a ação de salvamento. O Hub Central tem dois assentos de grupo separados. Qualquer regra que faça referência a “um” assento de grupo no Hub Central está se referindo a um dos dois assentos de grupo. P: O Quartel de Robótica é afetado pela regra de local de Tripulantes Robôs Erráticos? R: Não, essas regras só se aplicam aos robôs obtidos no local “Robótica” V.2. P: Podemos pegar de volta os dados colocados na cartela “Cisne Negro”? R: Não, eles farão parte do Cisne Negro até o final do episódio. P: Como o Habitat Deserto funciona agora que as regras do Cisne Negro estão em jogo? R: Os ícones impressos nos assentos do Habitat Deserto agora são considerados como marcadores permanentes naquele assento. O efeito “Traumatizado” impresso no Habitat Deserto agora é ignorado. P: Os quartéis de Robótica podem usar a habilidade de “Reprogramar” para remover um dado do Hangar de Robótica de um assento? R: Sim, mas aquele dado agora pertence ao Hangar de Robótica, e deve retornar para lá se for reprogramado."}

DOCUMENT30 = {
    "Título": "RESUMO DE UMA RODADA",
    "Conteúdo": "Para detalhes completos, consulte 'Rodada' na página 10. 1. TAREFAS CRÍTICAS Compre cartas de tarefa crítica, colocando-as na fila de tarefas críticas. RODADA 1 2 3+ 3 JOGADORES 1 Tarefa Crítica 2 Tarefas Críticas 4 JOGADORES 2 Tarefas Críticas 3 Tarefas Críticas 3 Tarefas Críticas 2. ROLAR A TRIPULAÇÃO Todos os jogadores rolam os dados de tripulante que estão na área 'alojamento da tripulação' das suas cartelas de quartel. 3. TURNOS DOS JOGADORES 4. FALHA DO SISTEMA 4 Tarefas Críticas Os jogadores farão suas jogadas em sentido horário a partir do chefe de operações, escolhendo dados de tripulante de seus quartéis e colocando-os em um assento desocupado. Cartas de tarefas críticas que não tiverem sido completadas ativam agora seus efeitos de falha do sistema, degradando o status dos sistemas afetados. 5. RECUPERAR A TRIPULAÇÃO Todos os jogadores recuperam seus dados de tripulante dos locais da nave e cartas e devolvem a tripulação robô para o suprimento. 6. ATUALIZAR O STATUS Marcadores de desabilitado são tirados dos assentos e marcadores de falha cobrem assentos em divisões com sistemas degradados. 7. FIM DA RODADA Os efeitos de fim da rodada acontecem, seguidos pelos efeitos de avanço da trama do fim da rodada. Se esta não for a rodada final, avance o marcador de rodada atual uma casa e volte para a fase 1."}


documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3, DOCUMENT4, DOCUMENT5,DOCUMENT6, DOCUMENT7,DOCUMENT8, DOCUMENT9,DOCUMENT10, DOCUMENT11,DOCUMENT12, DOCUMENT13,DOCUMENT14, DOCUMENT15,DOCUMENT16, DOCUMENT17,DOCUMENT18, DOCUMENT19,DOCUMENT20, DOCUMENT21,DOCUMENT22, DOCUMENT23,DOCUMENT24, DOCUMENT25, DOCUMENT26, DOCUMENT27, DOCUMENT28, DOCUMENT29, DOCUMENT30]


df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                                       Titulo  \
# 0                     SUMÁRIO PARA O OFICIAL
# 1                           OBJETIVO DO JOGO
# 2                                COMPONENTES
# 3                  CARTAS DE TAREFA CRÍTICA
# 4              CARTAS DE TAREFA DE OPERAÇÕES
# 5                          CARTAS DE ARQUIVO
# 6                          CARTAS DE ESQUEMA
# 7                     CARTAS DE ENCRUZILHADA
# 8             CARTAS DE OBJETIVO DE EPISÓDIO
# 9                 CARTAS DE OBJETIVO PESSOAL
# 10                      CARTAS DE TRIPULANTE
# 11                          CARTAS DE REGRAS
# 12              TABULEIROS DE LOCAIS DA NAVE
# 13                      TABULEIRO DE TRILHAS
# 14                        CARTELA DE QUARTEL
# 15                    PRIVILÉGIOS DE OFICIAL
# 16                            LIVRO DA TRAMA
# 17                        OUTROS COMPONENTES
# 18                                PREPARAÇÃO
# 19                                    RODADA
# ...

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                       Titulo  \
# 0                     SUMÁRIO PARA O OFICIAL
# 1                           OBJETIVO DO JOGO
# 2                                COMPONENTES
# 3                  CARTAS DE TAREFA CRÍTICA
# 4              CARTAS DE TAREFA DE OPERAÇÕES
# 5                          CARTAS DE ARQUIVO
# 6                          CARTAS DE ESQUEMA
# 7                     CARTAS DE ENCRUZILHADA
# 8             CARTAS DE OBJETIVO DE EPISÓDIO
# 9                 CARTAS DE OBJETIVO PESSOAL
# 10                      CARTAS DE TRIPULANTE
# 11                          CARTAS DE REGRAS
# 12              TABULEIROS DE LOCAIS DA NAVE
# 13                      TABULEIRO DE TRILHAS
# 14                        CARTELA DE QUARTEL
# 15                    PRIVILÉGIOS DE OFICIAL
# 16                            LIVRO DA TRAMA
# 17                        OUTROS COMPONENTES
# 18                                PREPARAÇÃO
# 19                                    RODADA
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %%
consulta = "Para que serve o livro de regras"

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# Nome: O nome da carta. 2. Regras: As regras que devem ser seguidas para usar os elementos de jogo referenciados. Essas cartas serão introduzidas quando um novo elemento entrar em jogo, e podem ser consultadas até esse elemento se tornar familiar.

# %%
generation_config = {
  "temperature": 0,
  "candidate_count": 1
}

# %%
prompt = f"encontre no texto a seguir apenas o trecho que responde apenas sobre {consulta}: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# Regras: As regras que devem ser seguidas para usar os elementos de jogo referenciados.
